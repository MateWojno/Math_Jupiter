# %% [markdown]
# # $$PL$$ `Spis tresci`
#
# ***
# ## `1. Liczby rzeczywiste`
#
# 1.1. Liczby naturalne
#
# Cechy podzielnosci liczb
#
# 1.2. Liczby calkowite. Liczby wymierne
#
# 1.3. Liczby niewymierne
#
# 1.4. Rozwiniecie dziesietne liczby rzeczywistej
#
# Dlugosc okregu. Liczba Pi - warto wiedziec
#
# 1.5. Pierwiastek kwadratowy
#
# 1.6. Pierwiastek szescienny
#
# 1.7. Potega o wykladniku calkowitym
#
# 1.8. Notacja wykladniczna
#
# 1.9. Potega o wykladniuku wymiernym
#
# 1.10. Logarytm i jego wlasnosci
#
# Skala logarytmiczna warto wiedziec
#
# 1.11 Procenty (1)
#
# 1.12 Procenty (2)
#
# 1.13 Zagadnienia uzupelniajace
# ***
#
#
# ## `2. Jezyk matematyki`
#
# 2.1. Zbiory
#
# 2.2. Dzialania na zbiorach
#
# Iloczyn kartezjanski zbiorow. Punkty kratowe - warto wiedziec
#
# 2.3. Przedzialy
#
# 2.4. Dzialania na przedzialach
#
# 2.5. Rozwiazywanie nierownosci
#
# Mnozenie sumy algebraicznej przez jednomian - warto powtorzyc
#
# 2.6. Wylaczanie jednomianu przed nawias
#
# 2.7. Mnozenie sum algebraicznych
#
# 2.8. Wzory skroconego mnozenia
#
# 2.9. Zastosowanie przeksztalcen algebraicznych
#
# Zastosowanie wzorow skroconego mnozenia w dowodach - warto wiedziec
#
# 2.10. Wartosc bezwzgledna
#
# Zasostowanie wartosci bezwzglednej w dowodach - warto wiedziec
#
# 2.11. Wlasnosci wartosci bezwzglednej
# ***
#
#
# ## `3. Uklady rownan`
#
# 3.1. Co to jest uklad rownan
#
# 3.2. Rozwiazywanie ukladow rownan metoda podstawiania
#
# 3.3. Rzowiazywanie ukladow rownan metoda przeciwnych wspolczynnikow
#
# 3.4. Uklady rownan zadania tekstowe (1 & 2)
# ***
#
#
# ## `4. Funkcje`
#
# 4.1. Pojecie funkcji
#
# 4.2. Szkicowanie wykresu funkcji (1 & 2)
#
# Inne przyklady wykresow funkcji - warto wiedziec
#
# 4.4. Monotonicznosc funkcji
#
# 4.5. Odczytywanie wlasnosci funkcji z wykresu (1 & 2)
#
# 4.7. Przesuwanie wykresu wzdluz osi OY
#
# 4.8. Przesuwanie wykresu wzdluz osi OX
#
# 4.9. Wektory w ukladzie wspolrzednych
#
# 4.10. Przesuniecie wykresu o wektor
#
# 4.11. Przeksztalcenie wykresu przez symetrie wzgledem osi ukladu wspolrzednych
#
# 4.12. Inne przeksztalcenia wykresu
#
# 4.13. Proporcjonalnosc odwrotna
# ***
#
#
# ## `5. Funkcja liniowa`
#
# 5.1. Wykres funkcji liniowej
#
# 5.2. Wlasnosci funkcji liniowej
#
# 5.3. Rownanie prostej na plaszczyznie
#
# 5.4. Wspolczynnik kierunkowy prostej
#
# 5.5. Warunek prostopadlosci prostych
#
# 5.6. Interpretacja geometryczna ukladu rownan liniowych
#
# 5.7. Uklady nierownosci liniowych
#
# Programowanie liniowe - warto wiedziec
#
# 5.8. Rowanania i nierownosci liniowe z parametrami
#
# 5.9. Funkcja liniowa - zastosowania
# ***
#
#
# ## `6. Planimetria`
#
# 6.1. Miary katow w trojkacie
#
# Punkty specjalne w trojkacie - warto wiedziec
#
# 6.2. Trojkaty przystajace
#
# 6.3. Twierdzenie Talesa
#
# 6.4. Wielokaty podobne
#
# 6.5. Trojkaty podobne
#
# Proste i odcinki pomocnicze - warto wiedziec
#
# 6.6. Pola wielokatow podobnych
#
# 6.7. Twierdzenie o dwusiecznej kata w trojkacie
# ***
#
#
# ## `7. Funkcja kwadratowa`
#
# 7.1. Wykres funkcji $f(x) = ax^2$
#
# 7.2. Przesuniecie wykresu funkcji $f(x) = ax^2$ o wektor
#
# 7.3. Postac kanoniczna i postac ogolna funkcji kwadratowej
#
# Obliczanie wartosci trojmianu kwadratowego - warto powtorzyc
#
# 7.4. Rownania kwadratowe (1 & 2)
#
# Szkicowanie paraboli - warto wiedziec
#
# 7.6. Postac iloczynowa funckji kwadratowej
#
# 7.7. Nierownosci kwadratowe
#
# ***

# %% [markdown]
# ## $$ENG$$ `Table of content` - nd to fix
#
# ## `1. Real numbers`
#
# 1.1 Natural numbers
#
# Divisibility characteristics of numbers
#
# 1.2 Whole numbers. Rational numbers
#
# 1.3 Irrational numbers
#
# 1.4 Decimal expansion of a real number.
#
# Length of a circle. The number Pi - what you need to know
#
# 1.5 The square root
#
# 1.6 The cubic root
#
# 1.7 A power with an integer exponent
#
# 1.8 Exponential notation
#
# 1.9 Prime power with a measurable term
#
# 1.10. Logarithm and its properties
#
# The logarithmic scale is worth knowing
#
# 1.11 Percentages (1)
#
# 1.12 Percentages (2)
#
# 1.13 Supplementary subjects
# ***
#
#
# ## `2. The language of mathematics`
#
# 2.1 Sets
#
# 2.2 Operations on sets
#
# Cartesian product of sets. Lattice points - it is useful to know
#
# Divisions
#
# 2.4 Working on compartments
#
# 2.5 Solving inequalities
#
# Multiplication of an algebraic sum by a univariate - worth repeating
#
# 2.6. Removing a binomial from parentheses
#
# 2.7 Multiplication of algebraic sums
#
# 2.8 Shortcut multiplication formulas
#
# 2.9 Application of algebraic transformations
#
# Use of abbreviated multiplication formulas in proofs - it is useful to know
#
# 2.10. Absolute value
#
# Use of absolute value in proofs - it is useful to know
#
# 2.11. Properties of absolute value
# ***
#
#
# ## `3. Equation systems`
#
# 3.1 What is an equation system
#
# 3.2 Solving equation systems by substitution
#
# 3.3 Solving equations of equations by the method of opposite coefficients
#
# 3.4 Solving equations of difference exercises (1 & 2)
# ***
#
#
# ## `4. Functions`
#
# 4.1 Concept of a function
#
# 4.2 Drawing the graph of a function (1 & 2)
#
# Other examples of graphs of functions - this is worth knowing
#
# 4.4 Monotonicity of a function
#
# Reading the properties of a function from the graph (1 & 2) 4.7.
#
# 4.7 Moving the graph along the OY axis
#
# 4.8 Scrolling the graph along the OX axis
#
# 4.9 Vectors in the coordinate system
#
# 4.10. Shifting the graph by a vector
#
# 4.11. Transformation of the graph by symmetry with respect to the axis of the coordinate system
#
# 4.12. Other graph transformations
#
# 4.13. Inverse proportionality
# ***
#
#
# ## `5. Linear function`
#
# 5.1 Graph of a linear function
#
# Properties of a linear function 5.3.
#
# 5.3 The gradient of a line on a plane
#
# Factor of direction of a line 5.5 Perpendicularity condition
#
# 5.5 Perpendicularity condition of lines
#
# 5.6 Geometric interpretation of a system of linear equations
#
# 5.7 Systems of linear inequalities
#
# Linear programming - what you need to know
#
# 5.8 Linear equations and inequalities with parameters
#
# 5.9 Linear functions - applications
# ***
#
#
# ## `6. Planimetry`
#
# 6.1 Measures of angles in a triangle
#
# Special points in a triangle - worth knowing
#
# 6.2 congruent triangles
#
# 6.3 Thales' theorem
#
# 6.4 Similar polygons
#
# 6.5 Similar triangles
#
# Lines and segments - this is worth knowing
#
# 6.6 Fields of similar polygons
#
# 6.7 Bisector of angle theorem in a triangle
# ***
#
#
# ## `7. Quadratic function`
#
# 7.1 The graph of the function $f(x) = ax^2$.
#
# 7.2 Shifting the graph of the function $f(x) = ax^2$ by a vector
#
# 7.3 Canonical form and general form of the quadratic function
#
# Calculating the value of a quadratic triangle - worth repeating
#
# 7.4 Quadratic regressions (1 & 2)
#
# Sketching a parabola - it is useful to know
#
# 7.6 The product form of a quadratic function
#
# 7.7 Quadratic inequalities
#
# ***
